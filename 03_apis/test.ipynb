# %%
# Let's load values from the .env file
from dotenv import dotenv_values

config = dotenv_values()

# define variables for the login
pg_user = config['POSTGRES_USER']  # align the key label with your .env file !
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = config['POSTGRES_SCHEMA']
pg_pass = config['POSTGRES_PASS']
pg_api_key  =config['X-RapidAPI-Key']

# %%
import requests

url = "https://meteostat.p.rapidapi.com/stations/monthly"

querystring = {"station":"10637","start":"2020-01-01","end":"2020-12-31"}

headers = {
	"x-rapidapi-key": pg_api_key, #use the value of env file
	"x-rapidapi-host": "meteostat.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'meta': {'generated': '2025-10-28 10:48:56'}, 'data': [{'date': '2020-01-01 00:00:00', 'tavg': 4.1, 'tmin': 1.0, 'tmax': 7.0, 'prcp': 36.9, 'wspd': None, 'pres': 1025.2, 'tsun': 3306}, {'date': '2020-02-01 00:00:00', 'tavg': 6.5, 'tmin': 2.4, 'tmax': 10.2, 'prcp': 78.9, 'wspd': None, 'pres': 1016.1, 'tsun': 4608}, {'date': '2020-03-01 00:00:00', 'tavg': 7.4, 'tmin': 2.3, 'tmax': 12.3, 'prcp': 47.9, 'wspd': None, 'pres': 1018.1, 'tsun': 11244}, {'date': '2020-04-01 00:00:00', 'tavg': 12.9, 'tmin': 5.1, 'tmax': 20.3, 'prcp': 21.8, 'wspd': None, 'pres': 1017.5, 'tsun': 18402}, {'date': '2020-05-01 00:00:00', 'tavg': 14.2, 'tmin': 7.4, 'tmax': 20.2, 'prcp': 31.1, 'wspd': None, 'pres': 1020.3, 'tsun': 18240}, {'date': '2020-06-01 00:00:00', 'tavg': 18.6, 'tmin': 12.6, 'tmax': 24.2, 'prcp': 44.4, 'wspd': None, 'pres': 1013.3, 'tsun': 13260}, {'date': '2020-07-01 00:00:00', 'tavg': 20.6, 'tmin': 13.9, 'tmax': 26.8, 'prcp': 15.5, 'wspd': None, 'pres': 1016.6, 'tsun': 16074}, {'date': '2020-08-01 00:00:00', 'tavg': 22.0, 'tmin': 16.2, 'tmax': 28.1, 'prcp': 76.0, 'wspd': None, 'pres': 1013.6, 'tsun': 12552}, {'date': '2020-09-01 00:00:00', 'tavg': 17.0, 'tmin': 10.9, 'tmax': 23.5, 'prcp': 32.0, 'wspd': None, 'pres': 1016.7, 'tsun': 13674}, {'date': '2020-10-01 00:00:00', 'tavg': 11.3, 'tmin': 7.3, 'tmax': 14.8, 'prcp': 60.7, 'wspd': None, 'pres': 1013.1, 'tsun': 3648}, {'date': '2020-11-01 00:00:00', 'tavg': 6.6, 'tmin': 3.0, 'tmax': 10.1, 'prcp': 16.2, 'wspd': None, 'pres': 1025.2, 'tsun': 5490}, {'date': '2020-12-01 00:00:00', 'tavg': 4.3, 'tmin': 1.8, 'tmax': 6.5, 'prcp': 81.1, 'wspd': None, 'pres': 1009.0, 'tsun': 1176}]}

# %%
import pprint

# %%
pprint.pprint(response.json())  # Print only the first 2 entries nicely

# inspect the data: string, dictionary, etc.
## json normalization
# Out:
# {'data': [{'date': '2020-01-01 00:00:00',
#            'prcp': 36.9,
#            'pres': 1025.2,
#            'tavg': 4.1,
#            'tmax': 7.0,
#            'tmin': 1.0,
#            'tsun': 3306,
#            'wspd': None},
#           {'date': '2020-02-01 00:00:00',
#            'prcp': 78.9,
#            'pres': 1016.1,
#            'tavg': 6.5,
#            'tmax': 10.2,
#            'tmin': 2.4,
#            'tsun': 4608,
#            'wspd': None},
#           {'date': '2020-03-01 00:00:00',
#            'prcp': 47.9,
#            'pres': 1018.1,
#            'tavg': 7.4,
#            'tmax': 12.3,
#            'tmin': 2.3,
#            'tsun': 11244,
#            'wspd': None},
#           {'date': '2020-04-01 00:00:00',
#            'prcp': 21.8,
#            'pres': 1017.5,
#            'tavg': 12.9,
#            'tmax': 20.3,
#            'tmin': 5.1,
#            'tsun': 18402,
#            'wspd': None},
#           {'date': '2020-05-01 00:00:00',
#            'prcp': 31.1,
#            'pres': 1020.3,
#            'tavg': 14.2,
#            'tmax': 20.2,
#            'tmin': 7.4,
#            'tsun': 18240,
#            'wspd': None},
#           {'date': '2020-06-01 00:00:00',
#            'prcp': 44.4,
#            'pres': 1013.3,
#            'tavg': 18.6,
#            'tmax': 24.2,
#            'tmin': 12.6,
#            'tsun': 13260,
#            'wspd': None},
#           {'date': '2020-07-01 00:00:00',
#            'prcp': 15.5,
#            'pres': 1016.6,
#            'tavg': 20.6,
#            'tmax': 26.8,
#            'tmin': 13.9,
#            'tsun': 16074,
#            'wspd': None},
#           {'date': '2020-08-01 00:00:00',
#            'prcp': 76.0,
#            'pres': 1013.6,
#            'tavg': 22.0,
#            'tmax': 28.1,
#            'tmin': 16.2,
#            'tsun': 12552,
#            'wspd': None},
#           {'date': '2020-09-01 00:00:00',
#            'prcp': 32.0,
#            'pres': 1016.7,
#            'tavg': 17.0,
#            'tmax': 23.5,
#            'tmin': 10.9,
#            'tsun': 13674,
#            'wspd': None},
#           {'date': '2020-10-01 00:00:00',
#            'prcp': 60.7,
#            'pres': 1013.1,
#            'tavg': 11.3,
#            'tmax': 14.8,
#            'tmin': 7.3,
#            'tsun': 3648,
#            'wspd': None},
#           {'date': '2020-11-01 00:00:00',
#            'prcp': 16.2,
#            'pres': 1025.2,
#            'tavg': 6.6,
#            'tmax': 10.1,
#            'tmin': 3.0,
#            'tsun': 5490,
#            'wspd': None},
#           {'date': '2020-12-01 00:00:00',
#            'prcp': 81.1,
#            'pres': 1009.0,
#            'tavg': 4.3,
#            'tmax': 6.5,
#            'tmin': 1.8,
#            'tsun': 1176,
#            'wspd': None}],
#  'meta': {'generated': '2025-10-28 10:48:56'}}

# %%
# If you see 200, the request succeeded ✅.
print(response.status_code)
# Out:
# 200

# %%
import requests

url = "https://meteostat.p.rapidapi.com/stations/monthly"

querystring = {"station":"10488","start":"2020-01-01","end":"2020-12-31"}

headers = {
	"x-rapidapi-key": pg_api_key,
	"x-rapidapi-host": "meteostat.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

pprint.pprint(response.json())
# Out:
# {'data': [{'date': '2020-01-01 00:00:00',
#            'prcp': 17.6,
#            'pres': 1023.7,
#            'tavg': 3.1,
#            'tmax': 6.1,
#            'tmin': 0.0,
#            'tsun': 3870,
#            'wspd': None},
#           {'date': '2020-02-01 00:00:00',
#            'prcp': 88.9,
#            'pres': 1013.1,
#            'tavg': 5.6,
#            'tmax': 8.8,
#            'tmin': 2.4,
#            'tsun': 3252,
#            'wspd': None},
#           {'date': '2020-03-01 00:00:00',
#            'prcp': 25.5,
#            'pres': 1018.6,
#            'tavg': 5.3,
#            'tmax': 9.6,
#            'tmin': 0.8,
#            'tsun': 10626,
#            'wspd': None},
#           {'date': '2020-04-01 00:00:00',
#            'prcp': 1.9,
#            'pres': 1018.4,
#            'tavg': 11.0,
#            'tmax': 16.7,
#            'tmin': 4.4,
#            'tsun': 17814,
#            'wspd': None},
#           {'date': '2020-05-01 00:00:00',
#            'prcp': 42.7,
#            'pres': 1019.6,
#            'tavg': 12.1,
#            'tmax': 17.5,
#            'tmin': 6.7,
#            'tsun': 12852,
#            'wspd': None},
#           {'date': '2020-06-01 00:00:00',
#            'prcp': 40.5,
#            'pres': 1012.5,
#            'tavg': 18.1,
#            'tmax': 23.4,
#            'tmin': 13.2,
#            'tsun': 11862,
#            'wspd': None},
#           {'date': '2020-07-01 00:00:00',
#            'prcp': 17.0,
#            'pres': 1015.9,
#            'tavg': 19.3,
#            'tmax': 25.2,
#            'tmin': 13.4,
#            'tsun': 15300,
#            'wspd': None},
#           {'date': '2020-08-01 00:00:00',
#            'prcp': 119.4,
#            'pres': 1013.6,
#            'tavg': 21.2,
#            'tmax': 26.7,
#            'tmin': 15.7,
#            'tsun': 13734,
#            'wspd': None},
#           {'date': '2020-09-01 00:00:00',
#            'prcp': 49.7,
#            'pres': 1016.9,
#            'tavg': 16.0,
#            'tmax': 21.4,
#            'tmin': 10.0,
#            'tsun': 13566,
#            'wspd': None},
#           {'date': '2020-10-01 00:00:00',
#            'prcp': 105.8,
#            'pres': 1012.6,
#            'tavg': 10.9,
#            'tmax': 14.0,
#            'tmin': 7.9,
#            'tsun': 4980,
#            'wspd': None},
#           {'date': '2020-11-01 00:00:00',
#            'prcp': 6.1,
#            'pres': 1024.8,
#            'tavg': 6.1,
#            'tmax': 9.4,
#            'tmin': 3.1,
#            'tsun': 6162,
#            'wspd': None},
#           {'date': '2020-12-01 00:00:00',
#            'prcp': 20.9,
#            'pres': 1010.1,
#            'tavg': 3.6,
#            'tmax': 5.9,
#            'tmin': 1.3,
#            'tsun': 5310,
#            'wspd': None}],
#  'meta': {'generated': '2025-10-28 11:26:12'}}
